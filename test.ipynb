# %%
# --- START OF FILE test.py ---

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime
import ccxt

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
import sys
sys.path.append("../FinRL-Library")
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

class CCXTDownloader:
    def __init__(self, exchange_name='binance', start_date='2020-01-01', end_date='2023-01-01', timeframe='1d'):
        self.exchange = getattr(ccxt, exchange_name)()
        self.start_date = start_date
        self.end_date = end_date
        self.timeframe = timeframe

    def get_data(self, ticker_list):
        all_data = []
        for ticker in ticker_list:
            print(f"Downloading {ticker} from {self.exchange.id}...")
            symbol = ticker + '/USDT' # Assuming USDT pairs for crypto
            
            # Convert start_date to milliseconds timestamp
            since = self.exchange.parse8601(self.start_date + 'T00:00:00Z')
            
            ohlcv = []
            while since < self.exchange.parse8601(self.end_date + 'T00:00:00Z'):
                fetched_data = self.exchange.fetch_ohlcv(symbol, self.timeframe, since)
                if not fetched_data:
                    break
                ohlcv.extend(fetched_data)
                since = ohlcv[-1][0] + self.exchange.parse_timeframe(self.timeframe) * 1000 # Move to the next timeframe
            
            if ohlcv:
                df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
                df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
                df['tic'] = ticker
                all_data.append(df)
            else:
                print(f"No data downloaded for {ticker}")

        if all_data:
            full_df = pd.concat(all_data, axis=0)
            full_df = full_df.sort_values(by=['timestamp', 'tic']).reset_index(drop=True)
            
            # Format to match the required output
            full_df.rename(columns={'timestamp': 'date'}, inplace=True)
            full_df['adjcp'] = full_df['close'] # For crypto, adjcp can be the same as close
            full_df['day'] = full_df['date'].dt.dayofweek
            
            return full_df[['date', 'open', 'high', 'low', 'close', 'adjcp', 'volume', 'tic', 'day']]
        else:
            return pd.DataFrame()

downloader = CCXTDownloader(start_date=config.TRAIN_START_DATE, end_date=config.TRAIN_END_DATE)
df = downloader.get_data(config_tickers.CRYPTO_10_TICKER)
print(f"DataFrame shape after data download: {df.shape}")

fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

df = fe.preprocess_data(df)
print(f"DataFrame shape after preprocessing: {df.shape}")

# --- CORRECTED DATA PROCESSING PIPELINE ---

# 1. Split data FIRST
train = data_split(df, '2018-04-30','2020-07-01')

# --- NEW STEP TO DENSIFY THE TRAINING DATA ---
# This ensures that every date has a row for every ticker, preventing shape mismatches.
print("Densifying training data...")
# Get the full range of dates and all unique tickers from the training set
all_dates = pd.to_datetime(train['date'].unique())
all_tickers = train['tic'].unique()
multi_index = pd.MultiIndex.from_product([all_dates, all_tickers], names=['date', 'tic'])

# Set the index and reindex to create a complete, dense frame.
# This will introduce NaNs for dates/tickers that were missing.
train = train.set_index(['date', 'tic'])
train = train.reindex(multi_index)

# Group by ticker and forward-fill the missing data.
# bfill is used to fill any remaining NaNs at the beginning of the data.
train = train.groupby(level='tic').ffill().bfill()

# Reset the index to bring 'date' and 'tic' back as columns
train.reset_index(inplace=True)
print("Data densification complete.")

# 2. Function to calculate and add covariance matrix to a dataframe
def add_covariance_matrix(data):
    # Sort and factorize index
    data = data.sort_values(['date', 'tic'], ignore_index=True)
    data.index = data.date.factorize()[0]
    
    cov_list = []
    return_list = []
    # look back is one year
    lookback = 252
    
    for i in range(lookback, len(data.index.unique())):
        data_lookback = data.loc[i - lookback:i, :]
        price_lookback = data_lookback.pivot_table(index='date', columns='tic', values='close')
        return_lookback = price_lookback.pct_change().dropna()
        return_list.append(return_lookback)

        if not return_lookback.empty and len(return_lookback) > 1:
            covs = return_lookback.cov().values
        else:
            # Handle case with insufficient data
            num_tickers = len(data['tic'].unique())
            covs = np.zeros((num_tickers, num_tickers))
        cov_list.append(covs)

    # Merge covariance data
    # Make sure to only use dates that have a calculated covariance matrix
    df_cov = pd.DataFrame({
        'date': data.date.unique()[lookback:],
        'cov_list': cov_list,
        'return_list': return_list
    })
    data = data.merge(df_cov, on='date')
    data = data.sort_values(['date', 'tic']).reset_index(drop=True)
    return data

# 3. Apply the function to the train set
train = add_covariance_matrix(train)

# --- FIX: SET A DAY-BASED INDEX FOR THE ENVIRONMENT ---
train.index = train.date.factorize()[0]

# --- END OF CORRECTION ---

import numpy as np
import pandas as pd
from gymnasium.utils import seeding
from gymnasium import spaces
import gymnasium
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gymnasium.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step


    """
    metadata = {'render.modes': ['human']}

# --- CORRECTED __init__ METHOD for StockPortfolioEnv ---

    def __init__(self,
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0):
        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list
        # --- FIX: ADD THE MISSING ATTRIBUTE ---
        self.model_name = self.__class__.__name__

        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,))
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+len(self.tech_indicator_list),self.state_space))
        
        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].iloc[0]
        
        tech_indicator_data = self.data[self.tech_indicator_list].values.T
        self.state = np.vstack((self.covs, tech_indicator_data))

        self.terminal = False
        self.turbulence_threshold = turbulence_threshold
        self.portfolio_value = self.initial_amount

        self.asset_memory = [self.initial_amount]
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]

    def step(self, actions):
        self.terminal = self.day >= len(self.df.index.unique())-1

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(),'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()

            plt.plot(self.portfolio_return_memory,'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() !=0:
              sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                       df_daily_return['daily_return'].std()
              print("Sharpe: ",sharpe)
            print("=================================")

            return self.state, self.reward, self.terminal, False, {}

        else:
            weights = self.softmax_normalization(actions)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day,:]
            self.covs = self.data['cov_list'].iloc[0]
            
            tech_indicator_data = self.data[self.tech_indicator_list].values.T
            self.state = np.vstack((self.covs, tech_indicator_data))

            # calcualte portfolio return
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values)-1)*weights)
            new_portfolio_value = self.portfolio_value*(1+portfolio_return)
            self.portfolio_value = new_portfolio_value

            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])
            self.asset_memory.append(new_portfolio_value)

            self.reward = new_portfolio_value

        return self.state, self.reward, self.terminal, False, {}

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        
        self.covs = self.data['cov_list'].iloc[0]
        
        tech_indicator_data = self.data[self.tech_indicator_list].values.T
        self.state = np.vstack((self.covs, tech_indicator_data))

        self.portfolio_value = self.initial_amount
        self.terminal = False
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]
        return self.state, {}

    def render(self, mode='human'):
        return self.state

    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output


    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']

        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        # The .reset() method of a VecEnv returns the initial observation
        obs = e.reset()
        # Return the environment and the initial observation
        return e, obs
        
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4

}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# Downloading BTC from binance...
# Downloading ETH from binance...
# Downloading XRP from binance...
# Downloading LTC from binance...
# Downloading BCH from binance...
# Downloading LINK from binance...
# Downloading DOT from binance...
# Downloading ADA from binance...
# Downloading MATIC from binance...
# Downloading SOL from binance...
# DataFrame shape after data download: (9000, 9)
# Successfully added technical indicators
# DataFrame shape after preprocessing: (9000, 17)
# Densifying training data...
# Data densification complete.
# Stock Dimension: 8, State Space: 8
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %%
# initialize
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c,
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# -----------------------------------------
# | time/                 |               |
# |    fps                | 744           |
# |    iterations         | 100           |
# |    time_elapsed       | 0             |
# |    total_timesteps    | 500           |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 99            |
# |    policy_loss        | 8.66e+10      |
# |    reward             | 2.5874964e+09 |
# |    reward_max         | 2.7905285e+09 |
# |    reward_mean        | 2.7006692e+09 |
# |    reward_min         | 2.5874964e+09 |
# |    std                | 0.996         |
# |    value_loss         | 7.22e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2892393204.2809153
# Sharpe:  0.686938027219528
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 653           |
# |    iterations         | 200           |
# |    time_elapsed       | 1             |
# |    total_timesteps    | 1000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 199           |
# |    policy_loss        | 1.09e+11      |
# |    reward             | 3.3316984e+09 |
# |    reward_max         | 3.6249016e+09 |
# |    reward_mean        | 3.4847565e+09 |
# |    reward_min         | 3.3316984e+09 |
# |    std                | 0.995         |
# |    value_loss         | 9.94e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4476767436.937126
# Sharpe:  0.6838021466036076
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 300           |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 1500          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 299           |
# |    policy_loss        | 7.05e+10      |
# |    reward             | 1.5799686e+09 |
# |    reward_max         | 1.7017496e+09 |
# |    reward_mean        | 1.6178232e+09 |
# |    reward_min         | 1.5606208e+09 |
# |    std                | 0.995         |
# |    value_loss         | 3.64e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1601708262.0182323
# Sharpe:  0.6858098596019913
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 646           |
# |    iterations         | 400           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 2000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 399           |
# |    policy_loss        | 4.54e+10      |
# |    reward             | 1.4535062e+09 |
# |    reward_max         | 1.5395611e+09 |
# |    reward_mean        | 1.4789166e+09 |
# |    reward_min         | 1.4373719e+09 |
# |    std                | 0.994         |
# |    value_loss         | 1.84e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1626292077.4589546
# Sharpe:  0.6862386307120594
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 648           |
# |    iterations         | 500           |
# |    time_elapsed       | 3             |
# |    total_timesteps    | 2500          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 499           |
# |    policy_loss        | 8.35e+10      |
# |    reward             | 2.507274e+09  |
# |    reward_max         | 2.5794353e+09 |
# |    reward_mean        | 2.53952e+09   |
# |    reward_min         | 2.493849e+09  |
# |    std                | 0.994         |
# |    value_loss         | 6.6e+19       |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3500440055.857253
# Sharpe:  0.6845397227297746
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 647           |
# |    iterations         | 600           |
# |    time_elapsed       | 4             |
# |    total_timesteps    | 3000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 599           |
# |    policy_loss        | 2.22e+08      |
# |    reward             | 6.5684065e+06 |
# |    reward_max         | 6.5684065e+06 |
# |    reward_mean        | 6.443967e+06  |
# |    reward_min         | 6.3494235e+06 |
# |    std                | 0.994         |
# |    value_loss         | 3.63e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:8560809271.486964
# Sharpe:  0.6849129721507324
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 700           |
# |    time_elapsed       | 5             |
# |    total_timesteps    | 3500          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 699           |
# |    policy_loss        | 1.34e+08      |
# |    reward             | 4.9027445e+06 |
# |    reward_max         | 4.9027445e+06 |
# |    reward_mean        | 4.577994e+06  |
# |    reward_min         | 4.389722e+06  |
# |    std                | 0.994         |
# |    value_loss         | 2.07e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2843549474.467532
# Sharpe:  0.6864661831333626
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 651           |
# |    iterations         | 800           |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 4000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 799           |
# |    policy_loss        | 1.36e+08      |
# |    reward             | 4.4572655e+06 |
# |    reward_max         | 4.6158475e+06 |
# |    reward_mean        | 4.493676e+06  |
# |    reward_min         | 4.336581e+06  |
# |    std                | 0.994         |
# |    value_loss         | 1.96e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5932080682.599127
# Sharpe:  0.6840029994536454
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 652           |
# |    iterations         | 900           |
# |    time_elapsed       | 6             |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 899           |
# |    policy_loss        | 1.87e+08      |
# |    reward             | 6.609456e+06  |
# |    reward_max         | 6.6595085e+06 |
# |    reward_mean        | 6.5446145e+06 |
# |    reward_min         | 6.2984775e+06 |
# |    std                | 0.993         |
# |    value_loss         | 4.27e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6297814252.440666
# Sharpe:  0.6840087509708612
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 651           |
# |    iterations         | 1000          |
# |    time_elapsed       | 7             |
# |    total_timesteps    | 5000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 999           |
# |    policy_loss        | 1.54e+08      |
# |    reward             | 5.5356875e+06 |
# |    reward_max         | 5.7483e+06    |
# |    reward_mean        | 5.5579365e+06 |
# |    reward_min         | 5.133455e+06  |
# |    std                | 0.992         |
# |    value_loss         | 1.94e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3520471393.241212
# Sharpe:  0.6870999156223319
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 651           |
# |    iterations         | 1100          |
# |    time_elapsed       | 8             |
# |    total_timesteps    | 5500          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1099          |
# |    policy_loss        | 9.75e+07      |
# |    reward             | 3.0888208e+06 |
# |    reward_max         | 3.1012832e+06 |
# |    reward_mean        | 3.041843e+06  |
# |    reward_min         | 2.9526905e+06 |
# |    std                | 0.992         |
# |    value_loss         | 7.47e+13      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2052716947.309708
# Sharpe:  0.6856028611817925
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 651           |
# |    iterations         | 1200          |
# |    time_elapsed       | 9             |
# |    total_timesteps    | 6000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1199          |
# |    policy_loss        | 6.12e+07      |
# |    reward             | 1.9913901e+06 |
# |    reward_max         | 2.0375718e+06 |
# |    reward_mean        | 1.9897695e+06 |
# |    reward_min         | 1.8998118e+06 |
# |    std                | 0.991         |
# |    value_loss         | 4.05e+13      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2826496575.2662783
# Sharpe:  0.6864023152936688
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 651       |
# |    iterations         | 1300      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -11.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1299      |
# |    policy_loss        | 1.76e+10  |
# |    reward             | 891837.25 |
# |    reward_max         | 891837.25 |
# |    reward_mean        | 876626.06 |
# |    reward_min         | 860157.4  |
# |    std                | 0.991     |
# |    value_loss         | 7.93e+18  |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 656           |
# |    iterations         | 1400          |
# |    time_elapsed       | 10            |
# |    total_timesteps    | 7000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1399          |
# |    policy_loss        | 1.16e+11      |
# |    reward             | 3.6044334e+09 |
# |    reward_max         | 3.6210102e+09 |
# |    reward_mean        | 3.4474719e+09 |
# |    reward_min         | 3.292473e+09  |
# |    std                | 0.992         |
# |    value_loss         | 1.15e+20      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3530661374.827678
# Sharpe:  0.6875634483833787
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 655           |
# |    iterations         | 1500          |
# |    time_elapsed       | 11            |
# |    total_timesteps    | 7500          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1499          |
# |    policy_loss        | 5.41e+10      |
# |    reward             | 2.0284306e+09 |
# |    reward_max         | 2.0284306e+09 |
# |    reward_mean        | 1.8902605e+09 |
# |    reward_min         | 1.759138e+09  |
# |    std                | 0.991         |
# |    value_loss         | 3.68e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2537669419.592564
# Sharpe:  0.6847807702323513
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 654           |
# |    iterations         | 1600          |
# |    time_elapsed       | 12            |
# |    total_timesteps    | 8000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1599          |
# |    policy_loss        | 8.4e+10       |
# |    reward             | 2.2568566e+09 |
# |    reward_max         | 2.7195407e+09 |
# |    reward_mean        | 2.581542e+09  |
# |    reward_min         | 2.2568566e+09 |
# |    std                | 0.992         |
# |    value_loss         | 6.99e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2380443537.9187317
# Sharpe:  0.6871977001495184
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 652           |
# |    iterations         | 1700          |
# |    time_elapsed       | 13            |
# |    total_timesteps    | 8500          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1699          |
# |    policy_loss        | 8.3e+10       |
# |    reward             | 2.628573e+09  |
# |    reward_max         | 2.628573e+09  |
# |    reward_mean        | 2.5023936e+09 |
# |    reward_min         | 2.411393e+09  |
# |    std                | 0.992         |
# |    value_loss         | 7.11e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2986617274.454616
# Sharpe:  0.6880514330179416
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 651           |
# |    iterations         | 1800          |
# |    time_elapsed       | 13            |
# |    total_timesteps    | 9000          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1799          |
# |    policy_loss        | 4.42e+10      |
# |    reward             | 1.1858815e+09 |
# |    reward_max         | 1.4125652e+09 |
# |    reward_mean        | 1.3241398e+09 |
# |    reward_min         | 1.1858815e+09 |
# |    std                | 0.991         |
# |    value_loss         | 2.22e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2092238203.2109182
# Sharpe:  0.6872222055805678
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 651           |
# |    iterations         | 1900          |
# |    time_elapsed       | 14            |
# |    total_timesteps    | 9500          |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 1899          |
# |    policy_loss        | 2.12e+08      |
# |    reward             | 6.90751e+06   |
# |    reward_max         | 6.90751e+06   |
# |    reward_mean        | 6.7066325e+06 |
# |    reward_min         | 6.5198225e+06 |
# |    std                | 0.99          |
# |    value_loss         | 4.56e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4211556580.4862494
# Sharpe:  0.6873705926035173
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 650          |
# |    iterations         | 2000         |
# |    time_elapsed       | 15           |
# |    total_timesteps    | 10000        |
# | train/                |              |
# |    entropy_loss       | -11.3        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 1999         |
# |    policy_loss        | 1.79e+08     |
# |    reward             | 4.171774e+06 |
# |    reward_max         | 5.130171e+06 |
# |    reward_mean        | 4.513489e+06 |
# |    reward_min         | 4.171774e+06 |
# |    std                | 0.99         |
# |    value_loss         | 3.07e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6865358550.555832
# Sharpe:  0.684879596681063
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 650           |
# |    iterations         | 2100          |
# |    time_elapsed       | 16            |
# |    total_timesteps    | 10500         |
# | train/                |               |
# |    entropy_loss       | -11.3         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2099          |
# |    policy_loss        | 1.35e+08      |
# |    reward             | 3.60977e+06   |
# |    reward_max         | 4.0638118e+06 |
# |    reward_mean        | 3.7871832e+06 |
# |    reward_min         | 3.60977e+06   |
# |    std                | 0.99          |
# |    value_loss         | 1.71e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2862611131.8880005
# Sharpe:  0.6847577276392831
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 650          |
# |    iterations         | 2200         |
# |    time_elapsed       | 16           |
# |    total_timesteps    | 11000        |
# | train/                |              |
# |    entropy_loss       | -11.3        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 2199         |
# |    policy_loss        | 1.88e+08     |
# |    reward             | 6.294199e+06 |
# |    reward_max         | 6.59926e+06  |
# |    reward_mean        | 6.410615e+06 |
# |    reward_min         | 6.294199e+06 |
# |    std                | 0.988        |
# |    value_loss         | 4.8e+14      |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2809627891.1336403
# Sharpe:  0.6861706425078073
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 2300          |
# |    time_elapsed       | 17            |
# |    total_timesteps    | 11500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2299          |
# |    policy_loss        | 2.35e+08      |
# |    reward             | 7.2867945e+06 |
# |    reward_max         | 7.2867945e+06 |
# |    reward_mean        | 6.9651865e+06 |
# |    reward_min         | 6.4761125e+06 |
# |    std                | 0.987         |
# |    value_loss         | 4.61e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3251175692.385793
# Sharpe:  0.6868850186522621
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 2400          |
# |    time_elapsed       | 18            |
# |    total_timesteps    | 12000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2399          |
# |    policy_loss        | 1.19e+08      |
# |    reward             | 3.3603468e+06 |
# |    reward_max         | 3.4565935e+06 |
# |    reward_mean        | 3.4029465e+06 |
# |    reward_min         | 3.3603468e+06 |
# |    std                | 0.987         |
# |    value_loss         | 1.4e+14       |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2416187113.557787
# Sharpe:  0.6858055922077619
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 2500          |
# |    time_elapsed       | 19            |
# |    total_timesteps    | 12500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2499          |
# |    policy_loss        | 6.41e+07      |
# |    reward             | 1.8958256e+06 |
# |    reward_max         | 1.8958256e+06 |
# |    reward_mean        | 1.8512628e+06 |
# |    reward_min         | 1.8027514e+06 |
# |    std                | 0.986         |
# |    value_loss         | 3.7e+13       |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2057136018.2768986
# Sharpe:  0.6869212892460478
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 648           |
# |    iterations         | 2600          |
# |    time_elapsed       | 20            |
# |    total_timesteps    | 13000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2599          |
# |    policy_loss        | 6.67e+07      |
# |    reward             | 2.331435e+06  |
# |    reward_max         | 2.357653e+06  |
# |    reward_mean        | 2.328414e+06  |
# |    reward_min         | 2.2957322e+06 |
# |    std                | 0.986         |
# |    value_loss         | 4.22e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 650           |
# |    iterations         | 2700          |
# |    time_elapsed       | 20            |
# |    total_timesteps    | 13500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2699          |
# |    policy_loss        | 8.7e+10       |
# |    reward             | 2.6711818e+09 |
# |    reward_max         | 2.7104886e+09 |
# |    reward_mean        | 2.670718e+09  |
# |    reward_min         | 2.6204544e+09 |
# |    std                | 0.986         |
# |    value_loss         | 7.35e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2458252615.264976
# Sharpe:  0.6867411659630097
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 650           |
# |    iterations         | 2800          |
# |    time_elapsed       | 21            |
# |    total_timesteps    | 14000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2799          |
# |    policy_loss        | 8.77e+10      |
# |    reward             | 2.8568182e+09 |
# |    reward_max         | 2.8568182e+09 |
# |    reward_mean        | 2.745647e+09  |
# |    reward_min         | 2.6162596e+09 |
# |    std                | 0.985         |
# |    value_loss         | 6.89e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3288312921.308588
# Sharpe:  0.687720790989049
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 2900          |
# |    time_elapsed       | 22            |
# |    total_timesteps    | 14500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2899          |
# |    policy_loss        | 9.64e+10      |
# |    reward             | 1.5993969e+09 |
# |    reward_max         | 1.8703122e+09 |
# |    reward_mean        | 1.6996737e+09 |
# |    reward_min         | 1.5522322e+09 |
# |    std                | 0.983         |
# |    value_loss         | 8.49e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3006645072.7099333
# Sharpe:  0.6875497811138467
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 3000          |
# |    time_elapsed       | 23            |
# |    total_timesteps    | 15000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 2999          |
# |    policy_loss        | 8.61e+10      |
# |    reward             | 2.8433213e+09 |
# |    reward_max         | 2.8674368e+09 |
# |    reward_mean        | 2.8070979e+09 |
# |    reward_min         | 2.7362875e+09 |
# |    std                | 0.983         |
# |    value_loss         | 7.58e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2957978447.5181456
# Sharpe:  0.6874443046116439
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 3100          |
# |    time_elapsed       | 23            |
# |    total_timesteps    | 15500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3099          |
# |    policy_loss        | 6.54e+10      |
# |    reward             | 1.8180425e+09 |
# |    reward_max         | 1.9098182e+09 |
# |    reward_mean        | 1.8562483e+09 |
# |    reward_min         | 1.8180425e+09 |
# |    std                | 0.982         |
# |    value_loss         | 3.53e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2514634051.8650317
# Sharpe:  0.6863131510836413
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 3200          |
# |    time_elapsed       | 24            |
# |    total_timesteps    | 16000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 1.79e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3199          |
# |    policy_loss        | 9.53e+07      |
# |    reward             | 3.4396422e+06 |
# |    reward_max         | 3.535849e+06  |
# |    reward_mean        | 3.4820955e+06 |
# |    reward_min         | 3.4396422e+06 |
# |    std                | 0.982         |
# |    value_loss         | 1.28e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3803223727.3392925
# Sharpe:  0.6843683412040451
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 649           |
# |    iterations         | 3300          |
# |    time_elapsed       | 25            |
# |    total_timesteps    | 16500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3299          |
# |    policy_loss        | 1.87e+08      |
# |    reward             | 5.4102705e+06 |
# |    reward_max         | 5.4717855e+06 |
# |    reward_mean        | 5.40448e+06   |
# |    reward_min         | 5.3551095e+06 |
# |    std                | 0.982         |
# |    value_loss         | 2.96e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4169599682.513064
# Sharpe:  0.687855669501303
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 648           |
# |    iterations         | 3400          |
# |    time_elapsed       | 26            |
# |    total_timesteps    | 17000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3399          |
# |    policy_loss        | 1.21e+08      |
# |    reward             | 3.9062965e+06 |
# |    reward_max         | 3.9754925e+06 |
# |    reward_mean        | 3.9239428e+06 |
# |    reward_min         | 3.8311838e+06 |
# |    std                | 0.981         |
# |    value_loss         | 1.66e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2547750165.742179
# Sharpe:  0.6852618850598016
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 648          |
# |    iterations         | 3500         |
# |    time_elapsed       | 26           |
# |    total_timesteps    | 17500        |
# | train/                |              |
# |    entropy_loss       | -11.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 3499         |
# |    policy_loss        | 1.99e+08     |
# |    reward             | 5.306359e+06 |
# |    reward_max         | 6.187188e+06 |
# |    reward_mean        | 5.848858e+06 |
# |    reward_min         | 5.306359e+06 |
# |    std                | 0.979        |
# |    value_loss         | 4.7e+14      |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2766834601.911959
# Sharpe:  0.686227355487372
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 646           |
# |    iterations         | 3600          |
# |    time_elapsed       | 27            |
# |    total_timesteps    | 18000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3599          |
# |    policy_loss        | 1.8e+08       |
# |    reward             | 5.205052e+06  |
# |    reward_max         | 5.653289e+06  |
# |    reward_mean        | 5.4874945e+06 |
# |    reward_min         | 5.205052e+06  |
# |    std                | 0.979         |
# |    value_loss         | 3.51e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3222877657.4709496
# Sharpe:  0.6854934028101992
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 646           |
# |    iterations         | 3700          |
# |    time_elapsed       | 28            |
# |    total_timesteps    | 18500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3699          |
# |    policy_loss        | 9.31e+07      |
# |    reward             | 2.7495762e+06 |
# |    reward_max         | 2.8982078e+06 |
# |    reward_mean        | 2.831187e+06  |
# |    reward_min         | 2.7495762e+06 |
# |    std                | 0.979         |
# |    value_loss         | 9.1e+13       |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3279705492.8909755
# Sharpe:  0.6847097504245157
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 645           |
# |    iterations         | 3800          |
# |    time_elapsed       | 29            |
# |    total_timesteps    | 19000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3799          |
# |    policy_loss        | 6.79e+07      |
# |    reward             | 2.2613872e+06 |
# |    reward_max         | 2.2970928e+06 |
# |    reward_mean        | 2.271603e+06  |
# |    reward_min         | 2.250507e+06  |
# |    std                | 0.978         |
# |    value_loss         | 5.03e+13      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4436399359.239781
# Sharpe:  0.6852927240940124
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 645           |
# |    iterations         | 3900          |
# |    time_elapsed       | 30            |
# |    total_timesteps    | 19500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3899          |
# |    policy_loss        | 6.27e+07      |
# |    reward             | 1.4534349e+06 |
# |    reward_max         | 1.5060862e+06 |
# |    reward_mean        | 1.4701314e+06 |
# |    reward_min         | 1.4513151e+06 |
# |    std                | 0.977         |
# |    value_loss         | 2.68e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 646           |
# |    iterations         | 4000          |
# |    time_elapsed       | 30            |
# |    total_timesteps    | 20000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 3999          |
# |    policy_loss        | 4.65e+10      |
# |    reward             | 1.3421976e+09 |
# |    reward_max         | 1.4340703e+09 |
# |    reward_mean        | 1.3669435e+09 |
# |    reward_min         | 1.3214222e+09 |
# |    std                | 0.977         |
# |    value_loss         | 2.14e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1321017524.8379233
# Sharpe:  0.68637200591395
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 645          |
# |    iterations         | 4100         |
# |    time_elapsed       | 31           |
# |    total_timesteps    | 20500        |
# | train/                |              |
# |    entropy_loss       | -11.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 4099         |
# |    policy_loss        | 2.21e+11     |
# |    reward             | 7.139963e+09 |
# |    reward_max         | 7.344743e+09 |
# |    reward_mean        | 7.171325e+09 |
# |    reward_min         | 6.99601e+09  |
# |    std                | 0.978        |
# |    value_loss         | 5.04e+20     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7409163522.038974
# Sharpe:  0.6836671707156401
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 645           |
# |    iterations         | 4200          |
# |    time_elapsed       | 32            |
# |    total_timesteps    | 21000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4199          |
# |    policy_loss        | 5.13e+10      |
# |    reward             | 1.845841e+09  |
# |    reward_max         | 1.845841e+09  |
# |    reward_mean        | 1.7598176e+09 |
# |    reward_min         | 1.6273358e+09 |
# |    std                | 0.978         |
# |    value_loss         | 2.73e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2694753906.3265905
# Sharpe:  0.6870736315804663
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 645           |
# |    iterations         | 4300          |
# |    time_elapsed       | 33            |
# |    total_timesteps    | 21500         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4299          |
# |    policy_loss        | 3.4e+11       |
# |    reward             | 1.0894225e+10 |
# |    reward_max         | 1.0894225e+10 |
# |    reward_mean        | 1.0163802e+10 |
# |    reward_min         | 9.772433e+09  |
# |    std                | 0.977         |
# |    value_loss         | 9.5e+20       |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:9076898928.120104
# Sharpe:  0.6851684460581604
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 645           |
# |    iterations         | 4400          |
# |    time_elapsed       | 34            |
# |    total_timesteps    | 22000         |
# | train/                |               |
# |    entropy_loss       | -11.2         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4399          |
# |    policy_loss        | 5.84e+10      |
# |    reward             | 1.6019547e+09 |
# |    reward_max         | 1.6943288e+09 |
# |    reward_mean        | 1.6471686e+09 |
# |    reward_min         | 1.6019547e+09 |
# |    std                | 0.976         |
# |    value_loss         | 2.92e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2489085136.531524
# Sharpe:  0.6869589989266306
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 644           |
# |    iterations         | 4500          |
# |    time_elapsed       | 34            |
# |    total_timesteps    | 22500         |
# | train/                |               |
# |    entropy_loss       | -11.1         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4499          |
# |    policy_loss        | 1.32e+08      |
# |    reward             | 3.4412045e+06 |
# |    reward_max         | 3.8801198e+06 |
# |    reward_mean        | 3.7025812e+06 |
# |    reward_min         | 3.4412045e+06 |
# |    std                | 0.975         |
# |    value_loss         | 1.73e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2505325786.9899373
# Sharpe:  0.6855348623803378
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 644           |
# |    iterations         | 4600          |
# |    time_elapsed       | 35            |
# |    total_timesteps    | 23000         |
# | train/                |               |
# |    entropy_loss       | -11.1         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4599          |
# |    policy_loss        | 1.42e+08      |
# |    reward             | 4.2271585e+06 |
# |    reward_max         | 4.3242155e+06 |
# |    reward_mean        | 4.2418945e+06 |
# |    reward_min         | 4.0643365e+06 |
# |    std                | 0.975         |
# |    value_loss         | 1.48e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3465173074.3813815
# Sharpe:  0.6855272530719694
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 644          |
# |    iterations         | 4700         |
# |    time_elapsed       | 36           |
# |    total_timesteps    | 23500        |
# | train/                |              |
# |    entropy_loss       | -11.1        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0002       |
# |    n_updates          | 4699         |
# |    policy_loss        | 1.45e+08     |
# |    reward             | 4.251119e+06 |
# |    reward_max         | 4.36865e+06  |
# |    reward_mean        | 4.245934e+06 |
# |    reward_min         | 4.189159e+06 |
# |    std                | 0.975        |
# |    value_loss         | 2.34e+14     |
# ----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:7405295627.256804
# Sharpe:  0.6842859618460825
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 644           |
# |    iterations         | 4800          |
# |    time_elapsed       | 37            |
# |    total_timesteps    | 24000         |
# | train/                |               |
# |    entropy_loss       | -11.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4799          |
# |    policy_loss        | 2.26e+08      |
# |    reward             | 6.4936345e+06 |
# |    reward_max         | 6.9285815e+06 |
# |    reward_mean        | 6.745716e+06  |
# |    reward_min         | 6.4936345e+06 |
# |    std                | 0.975         |
# |    value_loss         | 4.44e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4244081060.0722013
# Sharpe:  0.6873799822716241
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 644           |
# |    iterations         | 4900          |
# |    time_elapsed       | 38            |
# |    total_timesteps    | 24500         |
# | train/                |               |
# |    entropy_loss       | -11.1         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4899          |
# |    policy_loss        | 1.08e+08      |
# |    reward             | 3.5950895e+06 |
# |    reward_max         | 3.6559252e+06 |
# |    reward_mean        | 3.537197e+06  |
# |    reward_min         | 3.397141e+06  |
# |    std                | 0.975         |
# |    value_loss         | 1.2e+14       |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2281834984.781475
# Sharpe:  0.6847878924373115
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 644           |
# |    iterations         | 5000          |
# |    time_elapsed       | 38            |
# |    total_timesteps    | 25000         |
# | train/                |               |
# |    entropy_loss       | -11.1         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 4999          |
# |    policy_loss        | 1.08e+08      |
# |    reward             | 2.8048968e+06 |
# |    reward_max         | 2.833228e+06  |
# |    reward_mean        | 2.7540738e+06 |
# |    reward_min         | 2.594492e+06  |
# |    std                | 0.973         |
# |    value_loss         | 1.13e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3089284003.1842813
# Sharpe:  0.6859897345941747
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 644           |
# |    iterations         | 5100          |
# |    time_elapsed       | 39            |
# |    total_timesteps    | 25500         |
# | train/                |               |
# |    entropy_loss       | -11.1         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 5099          |
# |    policy_loss        | 6.69e+07      |
# |    reward             | 1.9992184e+06 |
# |    reward_max         | 1.9992184e+06 |
# |    reward_mean        | 1.9845394e+06 |
# |    reward_min         | 1.965244e+06  |
# |    std                | 0.972         |
# |    value_loss         | 3.97e+13      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1701704453.2476447
# Sharpe:  0.6854441514237981
# ...
# Sharpe:  0.6862174991913855
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 642           |
# |    iterations         | 8400          |
# |    time_elapsed       | 65            |
# |    total_timesteps    | 42000         |
# | train/                |               |
# |    entropy_loss       | -10.9         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8399          |
# |    policy_loss        | 4.41e+10      |
# |    reward             | 1.188888e+09  |
# |    reward_max         | 1.2891135e+09 |
# |    reward_mean        | 1.2518125e+09 |
# |    reward_min         | 1.188888e+09  |
# |    std                | 0.946         |
# |    value_loss         | 2e+19         |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1714828938.1146128
# Sharpe:  0.6865488380102609
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 642           |
# |    iterations         | 8500          |
# |    time_elapsed       | 66            |
# |    total_timesteps    | 42500         |
# | train/                |               |
# |    entropy_loss       | -10.9         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8499          |
# |    policy_loss        | 1.05e+08      |
# |    reward             | 3.3511698e+06 |
# |    reward_max         | 3.3511698e+06 |
# |    reward_mean        | 3.2615518e+06 |
# |    reward_min         | 3.2093375e+06 |
# |    std                | 0.944         |
# |    value_loss         | 1.1e+14       |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4630183170.5659075
# Sharpe:  0.6839530440920343
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 642           |
# |    iterations         | 8600          |
# |    time_elapsed       | 66            |
# |    total_timesteps    | 43000         |
# | train/                |               |
# |    entropy_loss       | -10.9         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8599          |
# |    policy_loss        | 1.57e+08      |
# |    reward             | 4.6349525e+06 |
# |    reward_max         | 5.687366e+06  |
# |    reward_mean        | 5.1105735e+06 |
# |    reward_min         | 4.5511185e+06 |
# |    std                | 0.943         |
# |    value_loss         | 3.54e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2383688534.197305
# Sharpe:  0.6882928962544403
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 642           |
# |    iterations         | 8700          |
# |    time_elapsed       | 67            |
# |    total_timesteps    | 43500         |
# | train/                |               |
# |    entropy_loss       | -10.9         |
# |    explained_variance | 1.19e-07      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8699          |
# |    policy_loss        | 1.56e+08      |
# |    reward             | 5.316845e+06  |
# |    reward_max         | 5.9749445e+06 |
# |    reward_mean        | 5.654762e+06  |
# |    reward_min         | 5.2571355e+06 |
# |    std                | 0.943         |
# |    value_loss         | 3.49e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3102728413.0579996
# Sharpe:  0.6872958609280445
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 642           |
# |    iterations         | 8800          |
# |    time_elapsed       | 68            |
# |    total_timesteps    | 44000         |
# | train/                |               |
# |    entropy_loss       | -10.9         |
# |    explained_variance | -2.38e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8799          |
# |    policy_loss        | 2.09e+08      |
# |    reward             | 6.170814e+06  |
# |    reward_max         | 6.6268775e+06 |
# |    reward_mean        | 6.36716e+06   |
# |    reward_min         | 6.166624e+06  |
# |    std                | 0.943         |
# |    value_loss         | 4.7e+14       |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3009044272.7830024
# Sharpe:  0.6861025760496735
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 642           |
# |    iterations         | 8900          |
# |    time_elapsed       | 69            |
# |    total_timesteps    | 44500         |
# | train/                |               |
# |    entropy_loss       | -10.9         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8899          |
# |    policy_loss        | 1.86e+08      |
# |    reward             | 5.9639505e+06 |
# |    reward_max         | 6.009878e+06  |
# |    reward_mean        | 5.8596945e+06 |
# |    reward_min         | 5.5093585e+06 |
# |    std                | 0.941         |
# |    value_loss         | 2.82e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2419037917.9410276
# Sharpe:  0.6880255823907501
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 9000          |
# |    time_elapsed       | 70            |
# |    total_timesteps    | 45000         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 8999          |
# |    policy_loss        | 1.24e+08      |
# |    reward             | 3.5995522e+06 |
# |    reward_max         | 3.688543e+06  |
# |    reward_mean        | 3.5668148e+06 |
# |    reward_min         | 3.4985652e+06 |
# |    std                | 0.939         |
# |    value_loss         | 1.48e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2128114216.3609624
# Sharpe:  0.6885019468823735
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 9100          |
# |    time_elapsed       | 70            |
# |    total_timesteps    | 45500         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 5.96e-08      |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9099          |
# |    policy_loss        | 6.91e+07      |
# |    reward             | 1.7705394e+06 |
# |    reward_max         | 1.831111e+06  |
# |    reward_mean        | 1.8108014e+06 |
# |    reward_min         | 1.7705394e+06 |
# |    std                | 0.938         |
# |    value_loss         | 3.61e+13      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1765347180.1371434
# Sharpe:  0.6866653880356217
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 9200          |
# |    time_elapsed       | 71            |
# |    total_timesteps    | 46000         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9199          |
# |    policy_loss        | 3.91e+07      |
# |    reward             | 1.3814759e+06 |
# |    reward_max         | 1.3884469e+06 |
# |    reward_mean        | 1.3719541e+06 |
# |    reward_min         | 1.3519136e+06 |
# |    std                | 0.939         |
# |    value_loss         | 1.39e+13      |
# -----------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 642           |
# |    iterations         | 9300          |
# |    time_elapsed       | 72            |
# |    total_timesteps    | 46500         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9299          |
# |    policy_loss        | 4.28e+10      |
# |    reward             | 1.4599612e+09 |
# |    reward_max         | 1.4969633e+09 |
# |    reward_mean        | 1.4717576e+09 |
# |    reward_min         | 1.4374674e+09 |
# |    std                | 0.938         |
# |    value_loss         | 2.13e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1346228529.730735
# Sharpe:  0.6863771120159721
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 642           |
# |    iterations         | 9400          |
# |    time_elapsed       | 73            |
# |    total_timesteps    | 47000         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9399          |
# |    policy_loss        | 7.2e+10       |
# |    reward             | 2.2703324e+09 |
# |    reward_max         | 2.2703324e+09 |
# |    reward_mean        | 2.1646817e+09 |
# |    reward_min         | 1.9957989e+09 |
# |    std                | 0.937         |
# |    value_loss         | 4.53e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2538324691.552904
# Sharpe:  0.6852267087048352
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 9500          |
# |    time_elapsed       | 73            |
# |    total_timesteps    | 47500         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9499          |
# |    policy_loss        | 9.1e+10       |
# |    reward             | 1.7397745e+09 |
# |    reward_max         | 2.804873e+09  |
# |    reward_mean        | 1.9278205e+09 |
# |    reward_min         | 1.5415726e+09 |
# |    std                | 0.936         |
# |    value_loss         | 9.79e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2857533668.3065085
# Sharpe:  0.6855463873037109
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 9600          |
# |    time_elapsed       | 74            |
# |    total_timesteps    | 48000         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9599          |
# |    policy_loss        | 7.4e+10       |
# |    reward             | 2.8277458e+09 |
# |    reward_max         | 2.8277458e+09 |
# |    reward_mean        | 2.773173e+09  |
# |    reward_min         | 2.7080317e+09 |
# |    std                | 0.936         |
# |    value_loss         | 6.96e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2910446890.7897205
# Sharpe:  0.6873508480105982
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 9700          |
# |    time_elapsed       | 75            |
# |    total_timesteps    | 48500         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | -1.19e-07     |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9699          |
# |    policy_loss        | 6.9e+10       |
# |    reward             | 2.0084934e+09 |
# |    reward_max         | 2.0760613e+09 |
# |    reward_mean        | 2.0243052e+09 |
# |    reward_min         | 1.9991517e+09 |
# |    std                | 0.935         |
# |    value_loss         | 4.05e+19      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2982938562.9075093
# Sharpe:  0.688221094920364
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 9800          |
# |    time_elapsed       | 76            |
# |    total_timesteps    | 49000         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9799          |
# |    policy_loss        | 2.62e+08      |
# |    reward             | 8.138219e+06  |
# |    reward_max         | 8.2149605e+06 |
# |    reward_mean        | 8.0993385e+06 |
# |    reward_min         | 8.0258435e+06 |
# |    std                | 0.934         |
# |    value_loss         | 6.86e+14      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3344541363.790015
# Sharpe:  0.6902071374579349
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 9900          |
# |    time_elapsed       | 77            |
# |    total_timesteps    | 49500         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9899          |
# |    policy_loss        | 9.63e+07      |
# |    reward             | 3.049046e+06  |
# |    reward_max         | 3.096437e+06  |
# |    reward_mean        | 3.0504205e+06 |
# |    reward_min         | 2.9778582e+06 |
# |    std                | 0.934         |
# |    value_loss         | 9.71e+13      |
# -----------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1762691763.2890925
# Sharpe:  0.6861135126138189
# =================================
# -----------------------------------------
# | time/                 |               |
# |    fps                | 641           |
# |    iterations         | 10000         |
# |    time_elapsed       | 77            |
# |    total_timesteps    | 50000         |
# | train/                |               |
# |    entropy_loss       | -10.8         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0002        |
# |    n_updates          | 9999          |
# |    policy_loss        | 1.63e+08      |
# |    reward             | 4.076185e+06  |
# |    reward_max         | 4.1926348e+06 |
# |    reward_mean        | 4.0864115e+06 |
# |    reward_min         | 3.9737415e+06 |
# |    std                | 0.934         |
# |    value_loss         | 1.67e+14      |
# -----------------------------------------

# %%
trained_a2c.save('./content/trained_models/trained_a2c.zip')

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=80000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:4564164797.908198
# Sharpe:  0.6836593088373951
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3399527914.014721
# Sharpe:  0.6854340164296723
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4042943901.547427
# Sharpe:  0.6891093076984665
# =================================
# --------------------------------------
# | time/              |               |
# |    fps             | 970           |
# |    iterations      | 1             |
# |    time_elapsed    | 2             |
# |    total_timesteps | 2048          |
# | train/             |               |
# |    reward          | 2.9896799e+09 |
# |    reward_max      | 6.231379e+09  |
# |    reward_mean     | 1.2438243e+09 |
# |    reward_min      | 847152.3      |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2667665258.968956
# Sharpe:  0.6862526864109054
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2042807941.9065382
# Sharpe:  0.6860951858379205
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:8398144979.394912
# Sharpe:  0.6845743041959327
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2108488439.6239295
# Sharpe:  0.6864243667574804
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 896           |
# |    iterations           | 2             |
# |    time_elapsed         | 4             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.21e+20      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | 1.53e-09      |
# |    reward               | 3.9947065e+06 |
# |    reward_max           | 1.0608256e+10 |
# |    reward_mean          | 1.2850172e+09 |
# |    reward_min           | 859436.6      |
# |    std                  | 1             |
# |    value_loss           | 1.15e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:6413574814.928798
# Sharpe:  0.6836309999078737
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:8264554822.372729
# Sharpe:  0.685104311047121
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1714599159.3144171
# Sharpe:  0.6858968535475172
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2620564511.7786813
# Sharpe:  0.6865736597663554
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 879           |
# |    iterations           | 3             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.34e+21      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -4.22e-09     |
# |    reward               | 7.041184e+06  |
# |    reward_max           | 1.1334845e+10 |
# |    reward_mean          | 1.8008861e+09 |
# |    reward_min           | 830756.2      |
# |    std                  | 1             |
# |    value_loss           | 1.73e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5980385001.203206
# Sharpe:  0.6857355864738021
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2697337073.381906
# Sharpe:  0.6852470731323174
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3175536945.213887
# Sharpe:  0.6845164134511259
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:8389144670.739297
# Sharpe:  0.6839428716068704
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 863           |
# |    iterations           | 4             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.42e+20      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | 9.14e-10      |
# |    reward               | 2.2506328e+06 |
# |    reward_max           | 1.0268984e+10 |
# |    reward_mean          | 1.8842044e+09 |
# |    reward_min           | 854606.7      |
# |    std                  | 1             |
# |    value_loss           | 2.71e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2740360755.0245113
# Sharpe:  0.6856450496723046
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1716754598.328825
# Sharpe:  0.6856000437953768
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3320377483.3127384
# Sharpe:  0.6846035469091009
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 865           |
# |    iterations           | 5             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.09e+21      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -4.66e-09     |
# |    reward               | 1.6988279e+09 |
# |    reward_max           | 4.4206264e+09 |
# |    reward_mean          | 8.6333184e+08 |
# |    reward_min           | 841312.8      |
# |    std                  | 1             |
# |    value_loss           | 2.65e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1782968176.406263
# Sharpe:  0.6852483746339882
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:8568366080.038048
# Sharpe:  0.6844861944638004
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5846442095.928657
# Sharpe:  0.684143736563954
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1351367572.2612367
# Sharpe:  0.6853768647779961
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 859           |
# |    iterations           | 6             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.4e+20       |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 7.09e-09      |
# |    reward               | 4.2528236e+09 |
# |    reward_max           | 1.1197576e+10 |
# |    reward_mean          | 1.6130436e+09 |
# |    reward_min           | 851513.06     |
# |    std                  | 1             |
# |    value_loss           | 5.27e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4590136715.61424
# Sharpe:  0.6842524092862694
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2496722856.9837856
# Sharpe:  0.6856092063609921
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2548883801.739614
# Sharpe:  0.6852709645240094
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2787019218.3353825
# Sharpe:  0.6858815105882855
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 855           |
# |    iterations           | 7             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.23e+21      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -1.92e-09     |
# |    reward               | 3.338919e+06  |
# |    reward_max           | 6.179476e+09  |
# |    reward_mean          | 1.0675137e+09 |
# |    reward_min           | 847745.4      |
# |    std                  | 1             |
# |    value_loss           | 2.46e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3164349640.9077444
# Sharpe:  0.6847648650056252
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1861186260.999671
# Sharpe:  0.6855967570368563
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:9986175666.740135
# Sharpe:  0.6845687127588499
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1927560692.4186494
# Sharpe:  0.6864859014145729
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 848           |
# |    iterations           | 8             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.74e+20      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -1.75e-09     |
# |    reward               | 4.0363162e+06 |
# |    reward_max           | 1.3233579e+10 |
# |    reward_mean          | 1.5686548e+09 |
# |    reward_min           | 829414.7      |
# |    std                  | 1             |
# |    value_loss           | 7.87e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2403136224.6515446
# Sharpe:  0.6843864161066977
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3106487227.9349155
# Sharpe:  0.6854120947773532
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2744976135.205132
# Sharpe:  0.6876282634264079
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3772540764.6075087
# Sharpe:  0.685090081245714
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 845           |
# |    iterations           | 9             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.12e+21      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -4.84e-09     |
# |    reward               | 1.5830949e+06 |
# |    reward_max           | 5.2060093e+09 |
# |    reward_mean          | 1.1325958e+09 |
# |    reward_min           | 824622.6      |
# |    std                  | 1             |
# |    value_loss           | 2.5e+21       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2137605294.6746447
# Sharpe:  0.6856227259063182
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:8386885729.482739
# Sharpe:  0.684196349540169
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3217606191.079068
# Sharpe:  0.6887932075969667
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 846           |
# |    iterations           | 10            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.55e+20      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -4.85e-09     |
# |    reward               | 3.479256e+09  |
# |    reward_max           | 1.0604723e+10 |
# |    reward_mean          | 1.5068344e+09 |
# |    reward_min           | 827144.9      |
# |    std                  | 1             |
# |    value_loss           | 8.25e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4611413670.130399
# Sharpe:  0.6865620644162884
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2633876408.53432
# Sharpe:  0.6861377942062258
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3736224100.5963564
# Sharpe:  0.6841292499045752
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2725758881.240946
# Sharpe:  0.6854228889591311
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 844           |
# |    iterations           | 11            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 7.35e+20      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -1.99e-09     |
# |    reward               | 1.7055131e+09 |
# |    reward_max           | 5.1599104e+09 |
# |    reward_mean          | 1.0491086e+09 |
# |    reward_min           | 857042.56     |
# |    std                  | 1             |
# |    value_loss           | 2e+21         |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2660543117.4999547
# Sharpe:  0.685561845175747
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3436386555.4212008
# Sharpe:  0.6868211537685855
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4356145134.530037
# Sharpe:  0.6842071896711867
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6288255583.367916
# Sharpe:  0.6846882459631782
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 842           |
# |    iterations           | 12            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.06e+20      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -2.13e-09     |
# |    reward               | 3.152037e+06  |
# |    reward_max           | 8.655606e+09  |
# |    reward_mean          | 1.5415873e+09 |
# |    reward_min           | 836928.94     |
# |    std                  | 1             |
# |    value_loss           | 7.97e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1760769436.585815
# Sharpe:  0.6857314340657067
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3653768668.659321
# Sharpe:  0.6853248443512064
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3315909018.9104786
# Sharpe:  0.6888458702635198
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1565083745.5132763
# Sharpe:  0.6847892587497166
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 839           |
# |    iterations           | 13            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.04e+21      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -3.76e-09     |
# |    reward               | 4.3963435e+06 |
# |    reward_max           | 4.627407e+09  |
# |    reward_mean          | 9.6711955e+08 |
# |    reward_min           | 853801.9      |
# |    std                  | 1             |
# |    value_loss           | 1.7e+21       |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4693076716.141614
# Sharpe:  0.6875030598647573
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2681606741.067602
# Sharpe:  0.6849168519029678
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2786944564.7888002
# Sharpe:  0.6869607966582274
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 837           |
# |    iterations           | 14            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.78e+20      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -1.67e-09     |
# |    reward               | 2.8597548e+09 |
# |    reward_max           | 6.2879514e+09 |
# |    reward_mean          | 1.2141225e+09 |
# |    reward_min           | 826278.7      |
# |    std                  | 1             |
# |    value_loss           | 6.56e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2859754780.462091
# Sharpe:  0.6857059807653676
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4422023978.556249
# Sharpe:  0.6859350937752648
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3494279530.37906
# Sharpe:  0.6854443584494389
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3002672939.592405
# Sharpe:  0.685145005676869
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 835           |
# |    iterations           | 15            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.03e+20      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | 4.56e-09      |
# |    reward               | 5.70637e+09   |
# |    reward_max           | 6.5846364e+09 |
# |    reward_mean          | 1.2411466e+09 |
# |    reward_min           | 851531.25     |
# |    std                  | 1             |
# |    value_loss           | 9.93e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4818083488.068914
# Sharpe:  0.6842087203252952
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2494415324.123013
# Sharpe:  0.6862929886865008
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:7601305224.6016035
# Sharpe:  0.6840334559179606
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5976965937.558342
# Sharpe:  0.684900841537684
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 833           |
# |    iterations           | 16            |
# |    time_elapsed         | 39            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.62e+20      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | 1.75e-11      |
# |    reward               | 3.4598022e+06 |
# |    reward_max           | 9.783348e+09  |
# |    reward_mean          | 1.7565985e+09 |
# |    reward_min           | 843846.3      |
# |    std                  | 1             |
# |    value_loss           | 1.12e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2350574032.821679
# Sharpe:  0.6857675962292636
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:8540268530.122643
# Sharpe:  0.6846351498312515
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3200063323.0678573
# Sharpe:  0.6839911536970339
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:9020765638.164076
# Sharpe:  0.6844763997405756
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 833           |
# |    iterations           | 17            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.19e+21      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | 1.92e-09      |
# |    reward               | 3.996895e+06  |
# |    reward_max           | 1.1257558e+10 |
# |    reward_mean          | 2.0875596e+09 |
# |    reward_min           | 823836.94     |
# |    std                  | 1             |
# |    value_loss           | 2.45e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3973500719.9947934
# Sharpe:  0.6839746604792329
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2980975366.3715057
# Sharpe:  0.6884721472642451
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3999821172.0843053
# Sharpe:  0.6857343621570181
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3257346518.7247906
# Sharpe:  0.6877713760257148
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 829           |
# |    iterations           | 18            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.05e+21      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -6.74e-10     |
# |    reward               | 3.9050175e+06 |
# |    reward_max           | 5.1964365e+09 |
# |    reward_mean          | 1.3149577e+09 |
# |    reward_min           | 853164.44     |
# |    std                  | 1             |
# |    value_loss           | 3.44e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3896265439.1299996
# Sharpe:  0.68605389457003
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3795359246.330911
# Sharpe:  0.6872371455336349
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2886945890.021882
# Sharpe:  0.6860097410886924
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 828           |
# |    iterations           | 19            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.52e+20      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -6.18e-09     |
# |    reward               | 1.9679942e+09 |
# |    reward_max           | 5.082857e+09  |
# |    reward_mean          | 1.1215604e+09 |
# |    reward_min           | 845792.06     |
# |    std                  | 1             |
# |    value_loss           | 1.09e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1961557039.228169
# Sharpe:  0.6852848758634138
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4757611966.942062
# Sharpe:  0.6853306731023742
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2301580276.3734417
# Sharpe:  0.6858267457270883
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2691714937.527351
# Sharpe:  0.6865809308584483
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 826           |
# |    iterations           | 20            |
# |    time_elapsed         | 49            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.99e+20      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -1.28e-08     |
# |    reward               | 2.4124961e+09 |
# |    reward_max           | 6.537381e+09  |
# |    reward_mean          | 1.0279149e+09 |
# |    reward_min           | 838620.9      |
# |    std                  | 1             |
# |    value_loss           | 8.66e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2508836419.671728
# Sharpe:  0.6856289183733402
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6316083271.964036
# Sharpe:  0.6849166893568128
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2362140725.3303943
# Sharpe:  0.686978747392466
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2152848827.3715034
# Sharpe:  0.6850222222338349
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 824           |
# |    iterations           | 21            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.62e+20      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | 1.16e-10      |
# |    reward               | 3.1624058e+06 |
# |    reward_max           | 8.283462e+09  |
# |    reward_mean          | 1.1874022e+09 |
# |    reward_min           | 861670.5      |
# |    std                  | 1             |
# |    value_loss           | 8.45e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2813511770.767046
# Sharpe:  0.6855063238969072
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:7622509054.314002
# Sharpe:  0.6841087527924494
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5995654965.704327
# Sharpe:  0.6837266682578697
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5655938308.971677
# Sharpe:  0.6872823078526575
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 822          |
# |    iterations           | 22           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0          |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 4.93e+20     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -2.85e-10    |
# |    reward               | 4.257713e+06 |
# |    reward_max           | 9.412229e+09 |
# |    reward_mean          | 2.040513e+09 |
# |    reward_min           | 844988.25    |
# |    std                  | 1            |
# |    value_loss           | 1.2e+21      |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2371436781.7654433
# Sharpe:  0.6861833833715686
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6776869684.78141
# Sharpe:  0.6840345329199571
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3713798813.625197
# Sharpe:  0.6844772718808034
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:8624563905.903597
# Sharpe:  0.683691525944754
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 821           |
# |    iterations           | 23            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.85e+21      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -1.7e-09      |
# |    reward               | 1.8629865e+06 |
# |    reward_max           | 1.1373378e+10 |
# |    reward_mean          | 1.97937e+09   |
# |    reward_min           | 839980.56     |
# |    std                  | 1             |
# |    value_loss           | 2.87e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5362442994.650593
# Sharpe:  0.6839142957723594
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3601397872.8850417
# Sharpe:  0.6840574025464218
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3300052872.9086847
# Sharpe:  0.685215329165991
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 820           |
# |    iterations           | 24            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.28e+21      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -5.12e-10     |
# |    reward               | 2.2387528e+09 |
# |    reward_max           | 7.0994074e+09 |
# |    reward_mean          | 1.3428739e+09 |
# |    reward_min           | 838416.8      |
# |    std                  | 1             |
# |    value_loss           | 3.01e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3118724947.774481
# Sharpe:  0.6874922427396911
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3485352438.2796297
# Sharpe:  0.6839928239753995
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1902532444.566221
# Sharpe:  0.6869467892414503
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4190638233.5400558
# Sharpe:  0.6864366827085321
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 819            |
# |    iterations           | 25             |
# |    time_elapsed         | 62             |
# |    total_timesteps      | 51200          |
# | train/                  |                |
# |    approx_kl            | 0.0            |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -11.4          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 6.89e+20       |
# |    n_updates            | 240            |
# |    policy_gradient_loss | -2.46e-09      |
# |    reward               | 1.2922156e+09  |
# |    reward_max           | 5.855343e+09   |
# |    reward_mean          | 1.03436365e+09 |
# |    reward_min           | 832539.6       |
# |    std                  | 1              |
# |    value_loss           | 1.31e+21       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2189012191.951872
# Sharpe:  0.6851784206697633
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4427462980.573401
# Sharpe:  0.687536243528576
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2277135805.4660378
# Sharpe:  0.6847324648084279
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1785431006.6109161
# Sharpe:  0.686231503829202
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 813           |
# |    iterations           | 26            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 5.15e+20      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -6.34e-10     |
# |    reward               | 5.2494435e+06 |
# |    reward_max           | 6.0039393e+09 |
# |    reward_mean          | 9.704232e+08  |
# |    reward_min           | 847994.8      |
# |    std                  | 1             |
# |    value_loss           | 8.22e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4414729446.763464
# Sharpe:  0.6851372953829867
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2723805204.872556
# Sharpe:  0.6864046836109416
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2786156412.248812
# Sharpe:  0.6852202803492916
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5975357552.889182
# Sharpe:  0.6840762112651396
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 813           |
# |    iterations           | 27            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.28e+20      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | 1.46e-09      |
# |    reward               | 3.0844678e+06 |
# |    reward_max           | 7.439205e+09  |
# |    reward_mean          | 1.4862006e+09 |
# |    reward_min           | 849777.7      |
# |    std                  | 1             |
# |    value_loss           | 6.91e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3474098464.962275
# Sharpe:  0.6868797849399829
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5337086222.152819
# Sharpe:  0.6838307393529892
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6336132634.317497
# Sharpe:  0.6851040859779262
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 813           |
# |    iterations           | 28            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 8.33e+20      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -1.43e-09     |
# |    reward               | 3.4314386e+09 |
# |    reward_max           | 8.472144e+09  |
# |    reward_mean          | 1.694056e+09  |
# |    reward_min           | 845053.25     |
# |    std                  | 1             |
# |    value_loss           | 1.51e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3374375055.276081
# Sharpe:  0.6848758913108838
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2584221262.345012
# Sharpe:  0.6872258591954558
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2421013429.761076
# Sharpe:  0.6844636882377464
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5723555882.37412
# Sharpe:  0.6843609019387147
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 812           |
# |    iterations           | 29            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.01e+21      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 3.03e-09      |
# |    reward               | 2.4120658e+09 |
# |    reward_max           | 7.3108925e+09 |
# |    reward_mean          | 1.0715395e+09 |
# |    reward_min           | 841998.06     |
# |    std                  | 1             |
# |    value_loss           | 1.95e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2063307030.2225168
# Sharpe:  0.6865961954403961
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3805350870.218908
# Sharpe:  0.6862815974477957
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5661725241.610702
# Sharpe:  0.6838089440199082
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5159987691.351467
# Sharpe:  0.6844266202833235
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 811           |
# |    iterations           | 30            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.31e+20      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | 6.34e-10      |
# |    reward               | 4.510813e+06  |
# |    reward_max           | 7.3952246e+09 |
# |    reward_mean          | 1.4637441e+09 |
# |    reward_min           | 834387.9      |
# |    std                  | 1             |
# |    value_loss           | 9.84e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2214461264.678005
# Sharpe:  0.6869117070905483
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4695447411.124329
# Sharpe:  0.6869468972190225
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2485417896.6641517
# Sharpe:  0.6861126597521651
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1809434954.3316333
# Sharpe:  0.6871728328941604
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 810           |
# |    iterations           | 31            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 7.62e+20      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | 2.39e-09      |
# |    reward               | 3.3578632e+06 |
# |    reward_max           | 5.8841047e+09 |
# |    reward_mean          | 1.0191645e+09 |
# |    reward_min           | 844888.7      |
# |    std                  | 1             |
# |    value_loss           | 1.63e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2292801300.8941984
# Sharpe:  0.6852198281223191
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2395993653.08765
# Sharpe:  0.6856754245052771
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2550936456.6611123
# Sharpe:  0.6864193661742972
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2558892853.7896757
# Sharpe:  0.6856191943865039
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 810           |
# |    iterations           | 32            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.5e+20       |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -8.34e-09     |
# |    reward               | 2.381533e+06  |
# |    reward_max           | 3.5244275e+09 |
# |    reward_mean          | 9.170596e+08  |
# |    reward_min           | 829479.25     |
# |    std                  | 1             |
# |    value_loss           | 7.51e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2241230543.9045672
# Sharpe:  0.6872078094857467
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2793927828.6123295
# Sharpe:  0.6867364855947911
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4193875159.169955
# Sharpe:  0.6844227713537622
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 809           |
# |    iterations           | 33            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.02e+20      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | 9.21e-09      |
# |    reward               | 3.265365e+09  |
# |    reward_max           | 5.456955e+09  |
# |    reward_mean          | 1.1187374e+09 |
# |    reward_min           | 824142.2      |
# |    std                  | 1             |
# |    value_loss           | 5.29e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3722742927.9962
# Sharpe:  0.684178717090585
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2201630785.2011065
# Sharpe:  0.6858177255108032
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:6044541414.214868
# Sharpe:  0.6844263641520832
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5385008866.878091
# Sharpe:  0.6844512773613256
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 808           |
# |    iterations           | 34            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 4.66e+20      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -9.87e-10     |
# |    reward               | 2.2717074e+09 |
# |    reward_max           | 8.130911e+09  |
# |    reward_mean          | 1.4094491e+09 |
# |    reward_min           | 845501.2      |
# |    std                  | 1             |
# |    value_loss           | 8.57e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2829162158.069289
# Sharpe:  0.6857956794157629
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2507774921.582468
# Sharpe:  0.6851726405115834
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1609177852.5605822
# Sharpe:  0.6858956068339183
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4727928508.068745
# Sharpe:  0.6837288837547858
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 807           |
# |    iterations           | 35            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 6.92e+20      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -2.15e-09     |
# |    reward               | 2.58279e+06   |
# |    reward_max           | 6.431074e+09  |
# |    reward_mean          | 1.0313199e+09 |
# |    reward_min           | 843687.56     |
# |    std                  | 1             |
# |    value_loss           | 1.61e+21      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1847218998.6522088
# Sharpe:  0.6849434787016894
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2635138875.982929
# Sharpe:  0.6848521952714006
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2431707184.218618
# Sharpe:  0.6844649046028422
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1837280303.1806536
# Sharpe:  0.6853742625340976
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 805           |
# |    iterations           | 36            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.93e+20      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -5.54e-09     |
# |    reward               | 3.9276178e+06 |
# |    reward_max           | 3.6220685e+09 |
# |    reward_mean          | 8.4133286e+08 |
# |    reward_min           | 838093.2      |
# |    std                  | 1             |
# |    value_loss           | 8.14e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2251875258.5776477
# Sharpe:  0.6850824935132346
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2187918407.968818
# Sharpe:  0.686575451422563
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3270087781.46062
# Sharpe:  0.6877104695887355
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3531008086.6486607
# Sharpe:  0.6848557495884593
# =================================
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 804            |
# |    iterations           | 37             |
# |    time_elapsed         | 94             |
# |    total_timesteps      | 75776          |
# | train/                  |                |
# |    approx_kl            | 0.0            |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -11.4          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0001         |
# |    loss                 | 2.3e+20        |
# |    n_updates            | 360            |
# |    policy_gradient_loss | -1.2e-09       |
# |    reward               | 2.1642805e+06  |
# |    reward_max           | 5.0431534e+09  |
# |    reward_mean          | 1.04881414e+09 |
# |    reward_min           | 848837.5       |
# |    std                  | 1              |
# |    value_loss           | 4.55e+20       |
# --------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2772047921.371047
# Sharpe:  0.6864339260333155
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2040055855.8674533
# Sharpe:  0.6865629395557417
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1973375449.8984175
# Sharpe:  0.6857956137237767
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 804          |
# |    iterations           | 38           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0          |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -11.4        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.71e+20     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -6.87e-09    |
# |    reward               | 4.003316e+09 |
# |    reward_max           | 7.125483e+09 |
# |    reward_mean          | 9.392683e+08 |
# |    reward_min           | 852666.7     |
# |    std                  | 1            |
# |    value_loss           | 7.31e+20     |
# ------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5230455050.320282
# Sharpe:  0.6837873845383784
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:4959823483.767288
# Sharpe:  0.6841002056228432
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5061883958.830366
# Sharpe:  0.6838941688826691
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:7587172030.954506
# Sharpe:  0.6839103723039031
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 804           |
# |    iterations           | 39            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 3.84e+20      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 5.62e-09      |
# |    reward               | 1.3039328e+09 |
# |    reward_max           | 1.0493572e+10 |
# |    reward_mean          | 1.8736988e+09 |
# |    reward_min           | 862822.94     |
# |    std                  | 1             |
# |    value_loss           | 7.15e+20      |
# -------------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1987455856.3826704
# Sharpe:  0.6848990871141476
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3212494231.1458364
# Sharpe:  0.6876911176685638
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3984110621.9782157
# Sharpe:  0.683751586746549
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3476010303.9354653
# Sharpe:  0.6864158368473848
# =================================
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 803           |
# |    iterations           | 40            |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.0           |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -11.4         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0001        |
# |    loss                 | 1.51e+21      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -3.07e-09     |
# |    reward               | 3.1915538e+06 |
# |    reward_max           | 5.2846874e+09 |
# |    reward_mean          | 1.1851512e+09 |
# |    reward_min           | 857063.5      |
# |    std                  | 1             |
# |    value_loss           | 2.63e+21      |
# -------------------------------------------

# %%
trained_ppo.save('./content/trained_models/trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_ddpg = agent.train_model(model=model_ddpg,
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:4981447.8010044675
# Sharpe:  0.8613296544165371
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 174       |
# |    time_elapsed    | 66        |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -8.42e+07 |
# |    critic_loss     | 5.81e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 5267437.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 157       |
# |    time_elapsed    | 147       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -1.74e+08 |
# |    critic_loss     | 2.01e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 5267437.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 151       |
# |    time_elapsed    | 229       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -2.24e+08 |
# |    critic_loss     | 2.45e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31823     |
# |    reward          | 5267437.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 148       |
# |    time_elapsed    | 312       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -2.52e+08 |
# |    critic_loss     | 1.98e+13  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43395     |
# |    reward          | 5267437.0 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:5267436.861472457
# Sharpe:  0.8789112048343828
# =================================

# %%
trained_ddpg.save('./content/trained_models/trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0003, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac,
                             tb_log_name='sac',
                             total_timesteps=50000)
# Out:
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# =================================
# begin_total_asset:1000000
# end_total_asset:5513749552.512651
# Sharpe:  0.6846155439901768
# =================================
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# =================================
# begin_total_asset:1000000
# end_total_asset:6831431008.843709
# Sharpe:  0.6849583538450336
# =================================
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# ...
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# =================================
# begin_total_asset:1000000
# end_total_asset:6831431008.843709
# Sharpe:  0.6849583538450336
# =================================
# -------------------------------------
# | time/              |              |
# |    episodes        | 92           |
# |    fps             | 91           |
# |    time_elapsed    | 541          |
# |    total_timesteps | 49772        |
# | train/             |              |
# |    actor_loss      | -1.83e+11    |
# |    critic_loss     | 3.73e+18     |
# |    ent_coef        | 3.13e+05     |
# |    ent_coef_loss   | -1.78e+03    |
# |    learning_rate   | 0.0003       |
# |    n_updates       | 49671        |
# |    reward          | 6.831431e+09 |
# |    reward_max      | None         |
# |    reward_mean     | None         |
# |    reward_min      | None         |
# -------------------------------------
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'

# %%
trained_sac.save('./content/trained_models/trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3,
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# =================================
# begin_total_asset:1000000
# end_total_asset:2552262019.213529
# Sharpe:  0.6881301265066349
# =================================
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# =================================
# begin_total_asset:1000000
# end_total_asset:2411186795.6964746
# Sharpe:  0.6882847865129688
# =================================
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# ...
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# =================================
# begin_total_asset:1000000
# end_total_asset:2411186795.6964746
# Sharpe:  0.6882847865129688
# =================================
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'
# Logging Error: 'rollout_buffer'

# %%
trained_td3.save('./content/trained_models/trained_td3.zip')

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
# Apply the same processing to the trade dataframe
trade = data_split(df, '2020-07-01', '2021-10-31')

# --- NEW STEP: Ensure consistent tickers across train and trade sets ---
# Filter the trade data to only include tickers present in the training data.
# This is crucial for ensuring the observation and action spaces match the trained model.
train_tickers = train.tic.unique()
trade = trade[trade['tic'].isin(train_tickers)].reset_index(drop=True)
print(f"Tickers in train: {len(train_tickers)}. Tickers in trade after filtering: {len(trade.tic.unique())}")


# 1. Densify the trading data
print("Densifying trading data...")
all_dates_trade = pd.to_datetime(trade['date'].unique())
all_tickers_trade = trade['tic'].unique()
multi_index_trade = pd.MultiIndex.from_product([all_dates_trade, all_tickers_trade], names=['date', 'tic'])

trade = trade.set_index(['date', 'tic'])
trade = trade.reindex(multi_index_trade)
trade = trade.groupby(level='tic').ffill().bfill()
trade.reset_index(inplace=True)
print("Trading data densification complete.")

# 2. Add covariance matrix to the trade set
trade = add_covariance_matrix(trade)

# 3. Set the day-based index for the environment
trade.index = trade.date.factorize()[0]

# --- END OF FIX ---

# Now, the trade environment will have the same dimensions as the train environment
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)
# Out:
# Tickers in train: 8. Tickers in trade after filtering: 8
# Densifying trading data...
# Trading data densification complete.

# %%
trade.shape
# Out:
# (1728, 19)

# %%
df_daily_return, df_actions = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1134432.9448877855
# Sharpe:  0.5803414343254688
# =================================
# hit end!

# %%
df_daily_return.head()
# Out:
#         date  daily_return
# 0 2021-03-10      0.000000
# 1 2021-03-11      0.010866
# 2 2021-03-12     -0.014560
# 3 2021-03-13      0.040658
# 4 2021-03-14     -0.022750

# %%
df_daily_return.to_csv('df_daily_return.csv')

# %%
df_actions.head()
# Out:
#                  ADA       BCH      BTC       ETH      LINK       LTC  \
# date
# 2021-03-10  0.125000  0.125000  0.12500  0.125000  0.125000  0.125000
# 2021-03-11  0.074179  0.074179  0.20164  0.159666  0.100483  0.114034
# 2021-03-12  0.074179  0.074179  0.20164  0.159666  0.100483  0.114034
# 2021-03-13  0.074179  0.074179  0.20164  0.159666  0.100483  0.114034
# 2021-03-14  0.074179  0.074179  0.20164  0.159666  0.100483  0.114034
#
#               MATIC       XRP
# date
# 2021-03-10  0.12500  0.125000
# 2021-03-11  0.20164  0.074179
# 2021-03-12  0.20164  0.074179
# 2021-03-13  0.20164  0.074179
# 2021-03-14  0.20164  0.074179

# %%
df_actions.to_csv('df_actions.csv')
